# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
events_path = "../data/events.csv"
events = pd.read_csv(events_path)

# %% [markdown]
# ### Parse Promotion Name

# %%
for index_label, row_series in events.iterrows():
    event_name = row_series["NAME"]
    promotion_name = event_name.split(" -",1)[0]
    
    # Check if last character is number
    if promotion_name[-1].isdigit():
        promotion_name = re.compile(r" [0-9]+$").split(promotion_name)[0]
        
    if promotion_name == "UFC Fight Night":
        promotion_name = "UFC"
        
    if promotion_name == "UFC on Fox":
        promotion_name = "UFC"
        
    if promotion_name == 'UFC Fight Night 6.5':
        promotion_name = "UFC"
        
    if promotion_name == 'PLMMA 17 Extra':
        promotion_name = "PLMMA"
        
    if promotion_name == "PLMMA 61 / AFC":
        promotion_name = "PLMMA"
        
    if promotion_name == 'PLMMA 26 Extra':
        promotion_name = "PLMMA"
        
    if promotion_name == "UFC on Fuel TV":
        promotion_name = "UFC"
        
    if promotion_name == "UFC on ESPN":
        promotion_name = "UFC"
        
    if promotion_name == "UFC Live":
        promotion_name = "UFC"
        
    if promotion_name == "UFC on FX":
        promotion_name = "UFC"
        
    if promotion_name == 'M-1 Selection':
        promotion_name = "M-1"
        
    if promotion_name == 'M-1 Challenge':
        promotion_name = "M-1"
        
    if promotion_name == 'M-1 Global':
        promotion_name = "M-1"
        
    if promotion_name == 'M-1 MFC':
        promotion_name = "M-1"
        
    if promotion_name == "Dana White's Tuesday Night Contender Series":
        promotion_name = "Dana White's Contender Series"
        
    if promotion_name == "Dana White's Tuesday Night Contender Series":
        promotion_name = "Dana White's Contender Series"
        
    if promotion_name == 'K-1 MAX':
        promotion_name = "K-1"
        
    if promotion_name == 'K-1 MMA':
        promotion_name = "K-1"
        
    if promotion_name == "K-1 HERO's":
        promotion_name = "K-1"
    
    if promotion_name == 'Lights Out / Bash Entertainment':
        promotion_name = 'Lights Out Championship'
    
    events.at[index_label , 'PROMOTION'] = promotion_name

# %%
events.head(10)
# Out:
#                                             NAME             DATE  \
# 0                     UFC 228 - Woodley vs. Till  Sep / 08 / 2018
# 1                   UFC 220 - Miocic vs. Ngannou  Jan / 20 / 2018
# 2                  UFC 218 - Holloway vs. Aldo 2  Dec / 02 / 2017
# 3  UFC Fight Night 109 - Gustafsson vs. Teixeira  May / 28 / 2017
# 4        UFC Fight Night 99 - Mousasi vs. Hall 2  Nov / 19 / 2016
# 5       LFC 61 - Legacy Fighting Championship 61  Oct / 14 / 2016
# 6   Rage in the Cage OKC 47 - Night of Champions  Aug / 13 / 2016
# 7                Bellator 143 - Warren vs. Davis  Sep / 25 / 2015
# 8                    RXMMA - Rocks Xtreme MMA 12  Feb / 28 / 2015
# 9                    Bellator MMA - Bellator 111  Mar / 07 / 2014
#
#               PROMOTION
# 0                   UFC
# 1                   UFC
# 2                   UFC
# 3                   UFC
# 4                   UFC
# 5                   LFC
# 6  Rage in the Cage OKC
# 7              Bellator
# 8                 RXMMA
# 9          Bellator MMA

# %% [markdown]
# ### Join Events to Fights table

# %%
fights_path = "../data/fights.csv"
fights = pd.read_csv(fights_path)
fighters_path = "../data/fighters.csv"
fighters = pd.read_csv(fighters_path)
fighters['fighter_index'] = fighters.index

# %%
events_fights = pd.merge(events, fights, left_on='NAME', right_on='Event')
events_fights_fighters = pd.merge(events_fights, fighters, left_on="Fighter", right_on="NAME")
events_fights_fighters.head()
# Out:
#                                           NAME_x             DATE PROMOTION  \
# 0                     UFC 228 - Woodley vs. Till  Sep / 08 / 2018       UFC
# 1                   UFC 220 - Miocic vs. Ngannou  Jan / 20 / 2018       UFC
# 2                  UFC 218 - Holloway vs. Aldo 2  Dec / 02 / 2017       UFC
# 3  UFC Fight Night 109 - Gustafsson vs. Teixeira  May / 28 / 2017       UFC
# 4        UFC Fight Night 99 - Mousasi vs. Hall 2  Nov / 19 / 2016       UFC
#
#                                            Event Win/Loss/Draw  \
# 0                     UFC 228 - Woodley vs. Till           WIN
# 1                   UFC 220 - Miocic vs. Ngannou           WIN
# 2                  UFC 218 - Holloway vs. Aldo 2           WIN
# 3  UFC Fight Night 109 - Gustafsson vs. Teixeira          LOSS
# 4        UFC Fight Night 99 - Mousasi vs. Hall 2           WIN
#
#                 Fighter        Opponent            Method         Referee  \
# 0  ABDUL RAZAK ALHASSAN      NIKO PRICE        KO (Punch)  Jacob Montalvo
# 1  ABDUL RAZAK ALHASSAN    SABAH HOMASI        KO (Punch)      Steve Rita
# 2  ABDUL RAZAK ALHASSAN    SABAH HOMASI     TKO (Punches)       Herb Dean
# 3  ABDUL RAZAK ALHASSAN  OMARI AKHMEDOV  Decision (Split)    Bobby Rehman
# 4  ABDUL RAZAK ALHASSAN    CHARLIE WARD        KO (Punch)    Marc Goddard
#
#    Round  Time  Closed Odds                NAME_y  GYM         DOB HEIGHT  \
# 0      1  0:43       -130.0  ABDUL RAZAK ALHASSAN  NaN  1985-08-11  5'10'
# 1      1  3:47       -250.0  ABDUL RAZAK ALHASSAN  NaN  1985-08-11  5'10'
# 2      1  4:21          NaN  ABDUL RAZAK ALHASSAN  NaN  1985-08-11  5'10'
# 3      3  5:00       -300.0  ABDUL RAZAK ALHASSAN  NaN  1985-08-11  5'10'
# 4      1  0:53       -330.0  ABDUL RAZAK ALHASSAN  NaN  1985-08-11  5'10'
#
#     WEIGHT  fighter_index
# 0  170 LBS              0
# 1  170 LBS              0
# 2  170 LBS              0
# 3  170 LBS              0
# 4  170 LBS              0

# %% [markdown]
# ### Loop through fighters and Add up UFC wins

# %%
for index_label, row_series in fighters.iterrows():
    fighter_name = fighters["NAME"].values[index_label]
    
    total_wins = len(events_fights[(events_fights.Fighter == fighter_name) & (events_fights["Win/Loss/Draw"] == "WIN")])
    total_losses = len(events_fights[(events_fights.Fighter == fighter_name) & (events_fights["Win/Loss/Draw"] == "LOSS")])

    ufc_wins = len(events_fights[(events_fights.Fighter == fighter_name) & (events_fights["Win/Loss/Draw"] == "WIN") & (events_fights['PROMOTION'] == "UFC")])
    ufc_losses = len(events_fights[(events_fights.Fighter == fighter_name) & (events_fights["Win/Loss/Draw"] == "LOSS") & (events_fights['PROMOTION'] == "UFC")])
    
    fighters.at[index_label , 'TOTAL_WINS'] = total_wins
    fighters.at[index_label , 'TOTAL_LOSSES'] = total_losses
    fighters.at[index_label , 'UFC_WINS'] = ufc_wins
    fighters.at[index_label , 'UFC_LOSSES'] = ufc_losses
    
fighters.head(10)
# Out:
#                    NAME                     GYM         DOB HEIGHT   WEIGHT  \
# 0  ABDUL RAZAK ALHASSAN                     NaN  1985-08-11  5'10'  170 LBS
# 1    ABDUL-KERIM EDILOV       Akhmat Fight Team  1991-11-25   6'3'  205 LBS
# 2           ABU AZAITAR            Team Azaitar  1986-03-10   5'9'  185 LBS
# 3         ADAM MILSTEAD   Pittsburgh Fight Club  1987-07-03   6'3'  205 LBS
# 4        ADAM WIECZOREK             AKS Chorzow  1992-02-05   6'5'  232 LBS
# 5          ADAM YANDIEV            Fight or Die  1988-07-07  5'11'  185 LBS
# 6          ADLAN AMAGOV        Jackson-Wink MMA  1986-10-30  5'11'  170 LBS
# 7        AIEMANN ZAHABI             Tristar Gym  1987-11-19   5'8'  135 LBS
# 8          AISLING DALY             SBG Ireland  1987-12-24   5'3'  116 LBS
# 9           AL IAQUINTA  Serra-Longo Fight Team  1987-04-30   5'7'  155 LBS
#
#    fighter_index  TOTAL_WINS  TOTAL_LOSSES  UFC_WINS  UFC_LOSSES
# 0              0        10.0           1.0       4.0         1.0
# 1              1        17.0           4.0       1.0         0.0
# 2              2        14.0           1.0       1.0         0.0
# 3              3         9.0           3.0       1.0         2.0
# 4              4        10.0           2.0       2.0         1.0
# 5              5         9.0           1.0       0.0         1.0
# 6              6        15.0           3.0       2.0         0.0
# 7              7         7.0           2.0       1.0         2.0
# 8              8        17.0           7.0       3.0         2.0
# 9              9        21.0           5.0      13.0         4.0

# %% [markdown]
# ### Map promotions to fighters

# %% [markdown]
# ##### Add an ASSOC_PROM column to each fighter with empty array

# %%
fighters['ASSOC_PROM'] = pd.np.empty((len(fighters), 0)).tolist()
fighters.head()
# Out:
#                    NAME                    GYM         DOB HEIGHT   WEIGHT  \
# 0  ABDUL RAZAK ALHASSAN                    NaN  1985-08-11  5'10'  170 LBS
# 1    ABDUL-KERIM EDILOV      Akhmat Fight Team  1991-11-25   6'3'  205 LBS
# 2           ABU AZAITAR           Team Azaitar  1986-03-10   5'9'  185 LBS
# 3         ADAM MILSTEAD  Pittsburgh Fight Club  1987-07-03   6'3'  205 LBS
# 4        ADAM WIECZOREK            AKS Chorzow  1992-02-05   6'5'  232 LBS
#
#    fighter_index  TOTAL_WINS  TOTAL_LOSSES  UFC_WINS  UFC_LOSSES ASSOC_PROM
# 0              0        10.0           1.0       4.0         1.0         []
# 1              1        17.0           4.0       1.0         0.0         []
# 2              2        14.0           1.0       1.0         0.0         []
# 3              3         9.0           3.0       1.0         2.0         []
# 4              4        10.0           2.0       2.0         1.0         []

# %% [markdown]
# ##### Map over events_fights_figthers. Map promotions into the fighter's array

# %%
for index_label, row_series in events_fights_fighters.iterrows():
    promotion = row_series['PROMOTION']
    fighter_index = row_series['fighter_index']
    assoc_prom = fighters.loc[fighter_index, 'ASSOC_PROM']
    if promotion not in assoc_prom: 
        assoc_prom.append(promotion)
        fighters.at[fighter_index, 'ASSOC_PROM'] = assoc_prom

# %% [markdown]
# ### Add up wins and losses by promoters

# %%
promotions = {}

for index_label, row_series in fighters.iterrows():
    assoc_promotions = row_series['ASSOC_PROM']
    ufc_wins = row_series["UFC_WINS"]
    ufc_losses = row_series["UFC_LOSSES"]
    for promotion in assoc_promotions:
        if promotion not in promotions:
            promotions[promotion] = {"ufc_wins": ufc_wins, "ufc_losses": ufc_losses}
        if promotion in promotions: 
            promotions[promotion]["ufc_wins"] += ufc_wins
            promotions[promotion]["ufc_losses"] += ufc_losses

# %% [markdown]
# ##### Sort by wins & losses

# %%
promotion_wins = []
ufc_wins = []

# Sort by wins
for v in sorted(promotions.items(), key=lambda item: item[1]["ufc_wins"]):
    promotion_wins.append(v[0])
    ufc_wins.append(v[1]['ufc_wins'])
    
promotion_losses = []
ufc_losses = []

# Sort by losses
for v in sorted(promotions.items(), key=lambda item: item[1]["ufc_losses"]):
    promotion_losses.append(v[0])
    ufc_losses.append(v[1]['ufc_losses'])

# %% [markdown]
# ### Plot Wins and Losses by Promotion

# %%
promotion_wins = promotion_wins[-21:-1]
ufc_wins = ufc_wins[-21:-1]

promotion_losses = promotion_losses[-21:-1]
ufc_losses = ufc_losses[-21:-1]

fig, axs = plt.subplots(2,1, figsize=(20, 10))
axs[0].bar(promotion_wins, ufc_wins)
axs[1].bar(promotion_losses, ufc_losses)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# ## Calculate win to loss ratio and plot

# %% [markdown]
# ##### Calculate Win & Loss Percentages

# %%
for name, record in promotions.items():
    ufc_wins, ufc_losses = [record[k] for k in ('ufc_wins', 'ufc_losses') ]
    total_fights = ufc_wins + ufc_losses
    win_perc = 0
    loss_perc = 0
    if total_fights:
        win_perc = ufc_wins/total_fights
        loss_perc = ufc_losses/total_fights
    else: 
        total_fights = 0
    promotions[name]["total_fights"] = total_fights
    promotions[name]["win_perc"] = win_perc
    promotions[name]["loss_perc"] = loss_perc
    
print(promotions)
# Out:
# {'UFC': {'ufc_wins': 3172.0, 'ufc_losses': 2125.0, 'total_fights': 5297.0, 'win_perc': 0.5988295261468756, 'loss_perc': 0.40117047385312443}, 'LFC': {'ufc_wins': 170.0, 'ufc_losses': 97.0, 'total_fights': 267.0, 'win_perc': 0.6367041198501873, 'loss_perc': 0.36329588014981273}, 'Rage in the Cage OKC': {'ufc_wins': 8.0, 'ufc_losses': 2.0, 'total_fights': 10.0, 'win_perc': 0.8, 'loss_perc': 0.2}, 'Bellator': {'ufc_wins': 44.0, 'ufc_losses': 34.0, 'total_fights': 78.0, 'win_perc': 0.5641025641025641, 'loss_perc': 0.4358974358974359}, 'RXMMA': {'ufc_wins': 16.0, 'ufc_losses': 9.0, 'total_fights': 25.0, 'win_perc': 0.64, 'loss_perc': 0.36}, 'Bellator MMA': {'ufc_wins': 106.0, 'ufc_losses': 81.0, 'total_fights': 187.0, 'win_perc': 0.5668449197860963, 'loss_perc': 0.43315508021390375}, 'XKO': {'ufc_wins': 52.0, 'ufc_losses': 29.0, 'total_fights': 81.0, 'win_perc': 0.6419753086419753, 'loss_perc': 0.35802469135802467}, 'WFCA': {'ufc_wins': 19.0, 'ufc_losses': 20.0, 'total_fights': 39.0, 'win_perc': 0.48717948717948717, 'loss_perc': 0.5128205128205128}, 'Fight Nights': {'ufc_wins': 43.0, 'ufc_losses': 20.0, 'total_fights': 63.0, 'win_perc': 0.6825396825396826, 'loss_perc': 0.31746031746031744}, 'ACB': {'ufc_wins': 38.0, 'ufc_losses': 26.0, 'total_fights': 64.0, 'win_perc': 0.59375, 'loss_perc': 0.40625}, 'Absolute Championship Berkut': {'ufc_wins': 7.0, 'ufc_losses': 4.0, 'total_fights': 11.0, 'win_perc': 0.6363636363636364, 'loss_perc': 0.36363636363636365}, 'CWFC': {'ufc_wins': 155.0, 'ufc_losses': 113.0, 'total_fights': 268.0, 'win_perc': 0.5783582089552238, 'loss_perc': 0.4216417910447761}, 'DFC': {'ufc_wins': 28.0, 'ufc_losses': 21.0, 'total_fights': 49.0, 'win_perc': 0.5714285714285714, 'loss_perc': 0.42857142857142855}, 'League S-70': {'ufc_wins': 24.0, 'ufc_losses': 4.0, 'total_fights': 28.0, 'win_perc': 0.8571428571428571, 'loss_perc': 0.14285714285714285}, 'ProFC': {'ufc_wins': 74.0, 'ufc_losses': 30.0, 'total_fights': 104.0, 'win_perc': 0.7115384615384616, 'loss_perc': 0.28846153846153844}, 'GFP': {'ufc_wins': 14.0, 'ufc_losses': 0.0, 'total_fights': 14.0, 'win_perc': 1.0, 'loss_perc': 0.0}, 'M-1': {'ufc_wins': 192.0, 'ufc_losses': 103.0, 'total_fights': 295.0, 'win_perc': 0.6508474576271186, 'loss_perc': 0.34915254237288135}, 'PAC': {'ufc_wins': 17.0, 'ufc_losses': 1.0, 'total_fights': 18.0, 'win_perc': 0.9444444444444444, 'loss_perc': 0.05555555555555555}, 'WSOF': {'ufc_wins': 117.0, 'ufc_losses': 81.0, 'total_fights': 198.0, 'win_perc': 0.5909090909090909, 'loss_perc': 0.4090909090909091}, 'GMC': {'ufc_wins': 6.0, 'ufc_losses': 7.0, 'total_fights': 13.0, 'win_perc': 0.46153846153846156, 'loss_perc': 0.5384615384615384}, 'KSW': {'ufc_wins': 36.0, 'ufc_losses': 26.0, 'total_fights': 62.0, 'win_perc': 0.5806451612903226, 'loss_perc': 0.41935483870967744}, 'KK': {'ufc_wins': 11.0, 'ufc_losses': 8.0, 'total_fights': 19.0, 'win_perc': 0.5789473684210527, 'loss_perc': 0.42105263157894735}, 'RFC': {'ufc_wins': 106.0, 'ufc_losses': 82.0, 'total_fights': 188.0, 'win_perc': 0.5638297872340425, 'loss_perc': 0.43617021276595747}, 'SFC': {'ufc_wins': 72.0, 'ufc_losses': 55.0, 'total_fights': 127.0, 'win_perc': 0.5669291338582677, 'loss_perc': 0.4330708661417323}, 'TFS': {'ufc_wins': 16.0, 'ufc_losses': 10.0, 'total_fights': 26.0, 'win_perc': 0.6153846153846154, 'loss_perc': 0.38461538461538464}, 'K1M': {'ufc_wins': 2.0, 'ufc_losses': 0.0, 'total_fights': 2.0, 'win_perc': 1.0, 'loss_perc': 0.0}, 'KOTC': {'ufc_wins': 471.0, 'ufc_losses': 358.0, 'total_fights': 829.0, 'win_perc': 0.5681544028950543, 'loss_perc': 0.43184559710494574}, 'GOTC MMA': {'ufc_wins': 4.0, 'ufc_losses': 5.0, 'total_fights': 9.0, 'win_perc': 0.4444444444444444, 'loss_perc': 0.5555555555555556}, 'Pinnacle FC': {'ufc_wins': 22.0, 'ufc_losses': 15.0, 'total_fights': 37.0, 'win_perc': 0.5945945945945946, 'loss_perc': 0.40540540540540543}, 'Gladiators of the Cage': {'ufc_wins': 9.0, 'ufc_losses': 8.0, 'total_fights': 17.0, 'win_perc': 0.5294117647058824, 'loss_perc': 0.4 ...

# %% [markdown]
# ##### Sort Win & Loss Percentages

# %%
promotion_perc_w = []
perc_wins = []

# Sort by percentage wins
for v in sorted(promotions.items(), key=lambda item: item[1]["win_perc"]):
    promotion_perc_w.append(v[0])
    perc_wins.append(v[1]['win_perc'])

#~~~~~#~~~~~#~~~~~#
promotion_perc_l = []
perc_losses = []

# Sort by percentage losses
for v in sorted(promotions.items(), key=lambda item: item[1]["loss_perc"]):
    promotion_perc_l.append(v[0])
    perc_losses.append(v[1]["loss_perc"])

# %% [markdown]
# ##### Print Win & Loss Plots

# %%
promotion_perc_w = promotion_perc_w[-21:-1]
perc_wins = perc_wins[-21:-1]

promotion_perc_l = promotion_perc_l[-21:-1]
perc_losses = perc_losses[-21:-1]

fig, axs = plt.subplots(2,1, figsize=(20, 10))
axs[0].bar(promotion_perc_w, perc_wins)
axs[1].bar(promotion_perc_l, perc_losses)
# Out:
# <BarContainer object of 20 artists>
